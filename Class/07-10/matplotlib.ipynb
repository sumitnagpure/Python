# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np # Often used for generating data

# %% [markdown]
# ## Plyplot

# %% [markdown]
# line plot

# %%
# Sample data
x_data = np.linspace(0, 10, 100)
y_data = np.sin(x_data)

# Create the plot
plt.figure(figsize=(8, 4)) # Sets the figure size (width, height) in inches
plt.plot(x_data, y_data, label='sin(x)', color='blue', linestyle='--')

# Add labels and a title
plt.title('Basic Line Plot of sin(x)')
plt.xlabel('X-Axis (Radians)')
plt.ylabel('Y-Axis (sin(x))')

# Add a legend and a grid
plt.legend()
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
# Sample categorical data
categories = ['A', 'B', 'C', 'D', 'E']
values = [23, 45, 55, 12, 78]

plt.figure(figsize=(7, 5))
# Create the bar chart
plt.bar(categories, values, color=['red', 'green', 'pink', 'orange', 'cyan'])

plt.title('Bar Chart of Category Values')
plt.xlabel('Category')
plt.ylabel('Value')

plt.show()

# %%
# Data from Section 1
quarters = ['Q1 2024', 'Q2 2024', 'Q3 2024', 'Q4 2024']
east_sales_k = [450, 520, 610, 750]
west_sales_k = [380, 410, 550, 680]
central_sales_k = [290, 350, 390, 480]

n_quarters = len(quarters)
bar_width = 0.25
index = np.arange(n_quarters)

plt.figure(figsize=(10, 6))

# Plotting the three groups, shifting their position by bar_width
plt.bar(index, east_sales_k, bar_width, label='East Region', color='skyblue')
plt.bar(index + bar_width, west_sales_k, bar_width, label='West Region', color='salmon')
plt.bar(index + 2 * bar_width, central_sales_k, bar_width, label='Central Region', color='lightgreen')

# Customizing
plt.xlabel('Quarter')
plt.ylabel('Sales (in $ Thousands)')
plt.title('Quarterly Sales Performance by Region')
plt.xticks(index + bar_width, quarters) # Center the labels under the group
plt.legend(title='Region')
plt.grid(axis='y', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Data for subplots
x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)

# Create a figure with 3 rows and 1 column of subplots
# 'fig' is the overall container, 'axes' is an array of the individual plots
fig, axes = plt.subplots(3, 1, figsize=(10, 8), sharex=True)

# Plot 1 (top)
axes[0].plot(x, y_sin, color='red')
axes[0].set_title('Sine Function')
axes[0].grid(True)

# Plot 2 (middle)
axes[1].plot(x, y_cos, color='green')
axes[1].set_title('Cosine Function')
axes[1].grid(True)

# Plot 3 (bottom)
# Note: Tangent explodes near pi/2 and 3pi/2, so we limit the y-axis
axes[2].plot(x, y_tan, color='blue')
axes[2].set_title('Tangent Function')
axes[2].set_ylim(-10, 10) # Set Y-axis limits
axes[2].grid(True)
axes[2].set_xlabel('X-Axis (Radians)') # Only label the bottom plot's X-axis

# Adjust the spacing between subplots for a clean look
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Histogram

# %%
# Sample data: 1000 random numbers following a normal distribution
data = np.random.randn(1000)

plt.figure(figsize=(8, 5))
# bins=30 means dividing the data range into 30 equally sized intervals
plt.hist(data, bins=30, color='purple', alpha=0.7, edgecolor='black')

plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.5)

plt.show()

# %% [markdown]
# ### Pie Chart

# %%
# --- 1. Meaningful Data ---
# Labels for each slice (Operating Systems)
labels = ['Windows', 'macOS', 'Linux', 'Android', 'iOS', 'Other']

# Sizes for each slice (Market Share Percentage)
sizes = [38.5, 15.2, 5.8, 25.1, 10.4, 5.0]

# Colors for better distinction (optional)
colors = ['#0078D4', '#555555', '#33CC33',
          '#A4C639', '#FF4500', '#AAAAAA']

# %%
plt.figure(figsize=(8,5))
plt.pie(sizes, labels=labels)
plt.title('Global OS Market Share')
plt.axis('equal')
plt.legend(labels,title='OS',loc="best")
plt.show()

# %%
# --- 2. Create the Pie Chart ---
plt.figure(figsize=(8, 5))
# 'Explode' a slice to emphasize it (e.g., emphasize Windows)
# Value of 0.1 means the slice will be offset by 10% of the radius
explode = (0.1, 0, 0, 0.2, 0, 0)
plt.pie(sizes,
        explode=explode,           # Apply the explode effect
        labels=labels,             # Labels for each slice
        colors=colors,             # Colors for each slice
        autopct='%1.1f%%',         # Format the percentage display (one decimal place)
        shadow=True,               # Add a subtle shadow
        startangle=90)             # Start the first slice at the top (90 degrees)

# Set the aspect ratio to 'equal' ensures the pie is circular
plt.axis('equal')

plt.title('Global OS Market Share Distribution', pad=20)
plt.legend(title="OS Categories", loc="lower left", bbox_to_anchor=(1, 0, 0.5, 1))

# Display the plot
plt.show()
